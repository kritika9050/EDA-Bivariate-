# %%
import pandas as pd
import seaborn as sns

# %%
# Assuming your_file.csv is located in the same directory as your Jupyter Notebook
file_path = "C:/Users/kritika/Desktop/your_file.xlsx"
# Use pandas to read the CSV file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to verify the import
df.head()
# Out:
#          PRODUCT      MOLECULE STRENGTH       QTY  RATES  SUGGESTED QUOTE  \
# 0      BLEOMYCIN     BLEOMYCIN     15IU   15687.0   7.55              NaN
# 1    VINCRISTINE   VINCRISTINE  1MG/1ML   27187.0   1.36              NaN
# 2   DACARBAZINE    DACARBAZINE    200MG   37070.0   4.21              NaN
# 3  FLUOROURACIL   FLUOROURACIL    500MG  364417.0   0.69              NaN
# 4    CYTARABINE     CYTARABINE    100MG   13710.0   1.28              NaN
#
#        VALUE STATUS  WINNING QTY.  WINNING VALUE  ...  FREQUENCY OF TENDER  \
# 0  118455.98    WON       15687.0   118455.98050  ...               1 year
# 1   37000.84    WON       27187.0    37000.84390  ...               1 year
# 2  155911.00   LOST       37070.0   155585.50240  ...               1 year
# 3  252780.96    WON      364417.0   252780.96290  ...               1 year
# 4   17575.55    WON       13710.0    17575.55122  ...               1 year
#
#           CATEGORY     L-1  L-1-rate  L-2 L-2-rate L-3  L-3-rate  \
# ...

# %%
sns.scatterplot(x=df['QTY'], y=df['RATES'], hue=df['MOLECULE'])
# Out:
# <Axes: xlabel='QTY', ylabel='RATES'>

# %%
df.head()
# Out:
#          PRODUCT      MOLECULE STRENGTH       QTY  RATES  SUGGESTED QUOTE  \
# 0      BLEOMYCIN     BLEOMYCIN     15IU   15687.0   7.55              NaN
# 1    VINCRISTINE   VINCRISTINE  1MG/1ML   27187.0   1.36              NaN
# 2   DACARBAZINE    DACARBAZINE    200MG   37070.0   4.21              NaN
# 3  FLUOROURACIL   FLUOROURACIL    500MG  364417.0   0.69              NaN
# 4    CYTARABINE     CYTARABINE    100MG   13710.0   1.28              NaN
#
#        VALUE STATUS  WINNING QTY.  WINNING VALUE  ...  FREQUENCY OF TENDER  \
# 0  118455.98    WON       15687.0   118455.98050  ...               1 year
# 1   37000.84    WON       27187.0    37000.84390  ...               1 year
# 2  155911.00   LOST       37070.0   155585.50240  ...               1 year
# 3  252780.96    WON      364417.0   252780.96290  ...               1 year
# 4   17575.55    WON       13710.0    17575.55122  ...               1 year
#
#           CATEGORY     L-1  L-1-rate  L-2 L-2-rate L-3  L-3-rate  \
# ...

# %%
sns.scatterplot(x=df['QTY'], y=df['RATES'])
# Out:
# <Axes: xlabel='QTY', ylabel='RATES'>

# %%
sns.boxplot(x=df['STATUS'], y=df['RATES'],hue=df['STATUS'])
# Out:
# <Axes: xlabel='STATUS', ylabel='RATES'>

# %%
sns.distplot(df['QTY'])
# Out:
# C:\Users\kritika\AppData\Local\Temp\ipykernel_62700\1302167092.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['QTY'])
# <Axes: xlabel='QTY', ylabel='Density'>

# %%
sns.heatmap(pd.crosstab(df['STATUS'],['MOLECULE']))
# Out:
# <Axes: xlabel='col_0', ylabel='STATUS'>

# %%
percentage_status_by_strength = df.groupby('STRENGTH')['STATUS'].value_counts(normalize=True) * 100

# %%
print(percentage_status_by_strength)
# Out:
# STRENGTH                   STATUS
# 100MG                      LOST        71.428571
#                            WON         14.285714
#                            0           14.285714
# 100MG/16.7ML               LOST       100.000000
# 10MG                       LOST       100.000000
# 150MG/15ML                 LOST       100.000000
# 15IU                       WON         50.000000
#                            LOST        50.000000
# 160MG                      0           50.000000
#                            LOST        50.000000
# 1G                         LOST        66.666667
#                            WON         33.333333
# 1MG/1ML                    WON        100.000000
# 200MG                      LOST        83.333333
#                            WON         16.666667
# 20MG                       LOST        33.333333
#                            AWAITED     33.333333
#                            0           33.333333
# ...

# %%
percentage_status_by_strength.plot(kind='bar')
# Out:
# <Axes: xlabel='STRENGTH,STATUS'>

# %%
sns.clustermap(pd.crosstab(df['QTY'], df['STATUS']))

# %%
sns.pairplot(df)
# Out:
# C:\Users\kritika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
